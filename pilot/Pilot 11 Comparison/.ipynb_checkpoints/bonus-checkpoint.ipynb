# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', None)

# %%
# #get rid of scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# import file
data_1 = pd.read_csv("data_exp_27347-v3_task-d7fe.csv", sep = ",")
data_2 = pd.read_csv("data_exp_27347-v3_task-yaom.csv", sep = ",")

# %%
data = pd.concat([data_1, data_2])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
data = data.replace('null', np.nan)
data  = data.replace('nan', np.nan)

# %%
data['start_time'] = round(data['start_time'].astype(float))

# %%
data_1 = data_1[['Participant Public ID', 'Participant Private ID', 'UTC Timestamp','key pressed', 'price_displayed', 'environment', 'task', 'function id',
       'builtin rt', 'end_time', 'start_time', 'response', 'round_instance']]

data_2 = data_2[['Participant Public ID', 'Participant Private ID', 'UTC Timestamp','key pressed', 'price_displayed', 'environment', 'task', 'function id',
       'builtin rt', 'end_time', 'start_time', 'response', 'round_instance']]

# %%
data = pd.concat([data_1, data_2])

# %%
data.rename(columns={"Participant Private ID": "Subject"}, inplace = True)
data.rename(columns={"Participant Public ID": 'external_id'}, inplace = True)
data.rename(columns={"UTC Timestamp": 'date'}, inplace = True)

# %%
data=data[(data.task == "fishing_pos")|(data.task == "fishing_neg")]

# %%
data.columns
# Out:
# Index(['external_id', 'Subject', 'date', 'key pressed', 'price_displayed',
#        'environment', 'task', 'function id', 'builtin rt', 'end_time',
#        'start_time', 'response', 'round_instance'],
#       dtype='object')

# %%
bonus = data.sort_values('date').groupby(["external_id","environment", "price_displayed", "task"]).size()
bonus = bonus.reset_index()
bonus.columns = ['id',"enviornment", 'price_displayed', 'factor', 'tap']
bonus = bonus.replace('fishing_pos', 4/3000)
bonus = bonus.replace('fishing_neg', 4/3000)
bonus = bonus.replace('rod_fixing', 0)
bonus.head(10)
# Out:
#                          id enviornment  price_displayed  factor  tap
# 0  5c48aa0551c26300012d04d9   post_mood            0.100   0.001  198
# 1  5c48aa0551c26300012d04d9   post_mood            0.400   0.001  204
# 2  5c48aa0551c26300012d04d9   post_mood            1.000   0.001  180
# 3  5c48aa0551c26300012d04d9   post_mood            2.500   0.001  161
# 4  5c48aa0551c26300012d04d9    pre_mood            0.100   0.001  123
# 5  5c48aa0551c26300012d04d9    pre_mood            0.400   0.001  179
# 6  5c48aa0551c26300012d04d9    pre_mood            1.000   0.001  191
# 7  5c48aa0551c26300012d04d9    pre_mood            2.500   0.001  171
# 8  5c5f33a97ba8710001f5e24d   post_mood            0.100   0.001  209
# 9  5c5f33a97ba8710001f5e24d   post_mood            0.400   0.001  189

# %%
bonus = bonus.round(20)
bonus['earning'] = bonus['price_displayed']*bonus['factor']*bonus['tap']
pay = bonus.groupby(['id', "enviornment"])['earning'].sum().reset_index()
pay['earning'] = np.ceil(pay['earning'])
pay['earning'] = pay["earning"]+1
pay['prolific'] = [','.join(i) for i in zip(pay["id"].map(str),pay["earning"].astype(str))]
pay = pay[pay.enviornment == "pre_mood"]
pay
# Out:
#                           id enviornment  earning  \
# 1   5c48aa0551c26300012d04d9    pre_mood    2.000
# 3   5c5f33a97ba8710001f5e24d    pre_mood    3.000
# 5   5cb71fcd98a1f100011c56fb    pre_mood    3.000
# 7   5d16539382c22b00155d9254    pre_mood    2.000
# 9   5d3ce45ffc93e20001ef8676    pre_mood    3.000
# 11  5d88ed51488d42001ed7796a    pre_mood    3.000
# 13  5df4b13aa1f36134572bf088    pre_mood    2.000
# 15  5e1c83bc110ee9000c7a2b9a    pre_mood    2.000
# 17  5e5d2201725a3503439aa5df    pre_mood    2.000
# 19  5e6a3f5c10df710aea15bea3    pre_mood    3.000
# 21  5e6a9a0bcbd6df04628b3844    pre_mood    2.000
# 23  5e6dbcacff04d638004faa15    pre_mood    2.000
# 25  5e820c95a7dfb990e185a7c8    pre_mood    3.000
# 27  5ea056fe72ae520009b99c71    pre_mood    2.000
# 29  5eaa806f42d336000a074b14    pre_mood    2.000
# 31  5eb1c85ebde80d31eb8fdda4    pre_mood    3.000
# 33  5ebf3541fa0189324a7cf56b    pre_mood    2.000
# 35  5eea650b40df2415e6b3f6f6    pre_mood    2.000
# 37  5f14cff323b6b655cbc821c3    pre_mood    3.000
# 39  5f15c2f29c4ae95abebb9787    pre_mood    2.000
# 41  5f161bb97eb01377e3f11075    pre_mood    2.000
# 43  5f1855cf1542050c468f9c3d    pre_mood    2.000
# 45  5f2af9bc1a903c473d55cb40    pre_mood    2.000
# 47  5f2d791bf61401045fc2684e    pre_mood    3.000
# 49  5f480180b6c229273889a39f    pre_mood    2.000
# 51  5f4e5955e4fe380175925821    pre_mood    2.000
# 53  5f50500950ebb81cfa392427    pre_mood    3.000
# 55  5f5176476494183c40718758    pre_mood    2.000
# 57  5f589a92ce1c040113809f03    pre_mood    2.000
# 59  5f68c29a2422a302ed2cbddf    pre_mood    2.000
#
#                         prolific
# 1   5c48aa0551c26300012d04d9,2.0
# 3   5c5f33a97ba8710001f5e24d,3.0
# 5   5cb71fcd98a1f100011c56fb,3.0
# 7   5d16539382c22b00155d9254,2.0
# 9   5d3ce45ffc93e20001ef8676,3.0
# 11  5d88ed51488d42001ed7796a,3.0
# 13  5df4b13aa1f36134572bf088,2.0
# 15  5e1c83bc110ee9000c7a2b9a,2.0
# 17  5e5d2201725a3503439aa5df,2.0
# 19  5e6a3f5c10df710aea15bea3,3.0
# 21  5e6a9a0bcbd6df04628b3844,2.0
# 23  5e6dbcacff04d638004faa15,2.0
# 25  5e820c95a7dfb990e185a7c8,3.0
# 27  5ea056fe72ae520009b99c71,2.0
# 29  5eaa806f42d336000a074b14,2.0
# 31  5eb1c85ebde80d31eb8fdda4,3.0
# 33  5ebf3541fa0189324a7cf56b,2.0
# 35  5eea650b40df2415e6b3f6f6,2.0
# 37  5f14cff323b6b655cbc821c3,3.0
# 39  5f15c2f29c4ae95abebb9787,2.0
# 41  5f161bb97eb01377e3f11075,2.0
# 43  5f1855cf1542050c468f9c3d,2.0
# 45  5f2af9bc1a903c473d55cb40,2.0
# 47  5f2d791bf61401045fc2684e,3.0
# 49  5f480180b6c229273889a39f,2.0
# 51  5f4e5955e4fe380175925821,2.0
# 53  5f50500950ebb81cfa392427,3.0
# 55  5f5176476494183c40718758,2.0
# 57  5f589a92ce1c040113809f03,2.0
# 59  5f68c29a2422a302ed2cbddf,2.0

# %%
np.sum(pay["earning"]) # 95
# 80
95 + 80 +
# Out:
# 70.0

# %%
pay.to_csv("sept_28_bonus_1_pilot_bonus.csv")
