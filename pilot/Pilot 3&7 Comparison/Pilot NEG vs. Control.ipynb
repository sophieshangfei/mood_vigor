# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as ss

# %%
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', None)

# %%
# #get rid of scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Import

# %%
# import file
data_neg = pd.read_csv('data_neg_02_latency_backfilled_happiness.csv', sep = ",")
data_control = pd.read_csv('data_2_no_wof_latency_backfilled_happiness.csv', sep = ",")

# %%
data_control= data_control[~data_control.Subject.isin([1997032])]

# %%
data_neg["label"] = ['neg']*len(data_neg)
data_control["label"] = ['control']*len(data_control)

# %%
data = pd.concat([data_neg, data_control])

# %%
data_neg.head(800)
# Out:
#      Unnamed: 0  index     Subject     UTC Timestamp  key pressed  \
# 0             6      6 1932451.000 1599581939418.000       40.000
# 1             7      7 1932451.000 1599581939418.000       40.000
# 2             8      8 1932451.000 1599581939793.000       40.000
# 3            10     10 1932451.000 1599581940496.000       40.000
# 4            12     12 1932451.000 1599581940652.000       40.000
# 5            13     13 1932451.000 1599581941012.000       40.000
# 6            14     14 1932451.000 1599581941184.000       40.000
# 7            15     15 1932451.000 1599581941184.000       40.000
# 8            16     16 1932451.000 1599581941559.000       40.000
# 9            17     17 1932451.000 1599581941559.000       40.000
# 10           19     19 1932451.000 1599581942121.000       40.000
# 11           20     20 1932451.000 1599581942121.000       40.000
# 12           21     21 1932451.000 1599581942121.000       40.000
# 13           22     22 1932451.000 1599581942121.000       40.000
# 14           23     23 1932451.000 1599581942980.000       40.000
# 15           24     24 1932451.000 1599581943152.000       40.000
# 16           25     25 1932451.000 1599581943152.000       40.000
# 17           26     26 1932451.000 1599581943152.000       40.000
# 18           28     28 1932451.000 1599581943324.000       40.000
# 19           29     29 1932451.000 1599581943324.000       40.000
# 20           30     30 1932451.000 1599581943684.000       40.000
# 21           31     31 1932451.000 1599581943856.000       40.000
# 22           32     32 1932451.000 1599581943856.000       40.000
# 23           36     36 1932451.000 1599581945121.000       40.000
# 24           38     38 1932451.000 1599581945480.000       40.000
# 25           48     48 1932451.000 1599581949152.000       40.000
# 26           49     49 1932451.000 1599581949152.000       40.000
# 27           50     50 1932451.000 1599581949324.000       40.000
# 28           51     51 1932451.000 1599581949324.000       40.000
# 29           52     52 1932451.000 1599581949652.000       40.000
# 30           55     55 1932451.000 1599581950605.000       40.000
# 31           56     56 1932451.000 1599581950605.000       40.000
# 32           57     57 1932451.000 1599581950949.000       40.000
# 33           58     58 1932451.000 1599581951122.000       40.000
# 34           59     59 1932451.000 1599581951122.000       40.000
# 35           60     60 1932451.000 1599581951122.000       40.000
# 36           61     61 1932451.000 1599581951466.000       40.000
# 37           62     62 1932451.000 1599581951638.000       40.000
# 38           63     63 1932451.000 1599581951638.000       40.000
# 39           64     64 1932451.000 1599581951810.000       40.000
# 40           65     65 1932451.000 1599581951810.000       40.000
# 41           66     66 1932451.000 1599581952169.000       40.000
# 42           67     67 1932451.000 1599581952356.000       40.000
# 43           68     68 1932451.000 1599581952356.000       40.000
# 44           69     69 1932451.000 1599581952356.000       40.000
# 45           70     70 1932451.000 1599581952700.000       40.000
# 46           71     71 1932451.000 1599581952859.000       40.000
# 687         917    917 1932451.000 1599582145864.000       40.000
# 688         918    918 1932451.000 1599582146209.000       40.000
# 689         919    919 1932451.000 1599582146395.000       40.000
# 690         920    920 1932451.000 1599582146395.000       40.000
# 691         921    921 1932451.000 1599582146395.000       40.000
# 692         922    922 1932451.000 1599582146865.000       40.000
# 693         923    923 1932451.000 1599582147067.000       40.000
# ...
# 542   post_mood 1.0                   1  neg  118.000   neg
# 543   post_mood 1.0                   1  neg  107.000   neg
# 544   post_mood 1.0                   1  neg  200.000   neg
# 545   post_mood 1.0                   1  neg  156.000   neg
# 546   post_mood 1.0                   1  neg  171.000   neg
# 547   post_mood 1.0                   1  neg  114.000   neg
# 548   post_mood 1.0                   1  neg  174.000   neg
# 549   post_mood 1.0                   1  neg  123.000   neg
# 550   post_mood 1.0                   1  neg  106.000   neg
# 551   post_mood 1.0                   1  neg  123.000   neg
# 552   post_mood 1.0                   1  neg  114.000   neg
# 553   post_mood 1.0                   1  neg  161.000   neg
# 554   post_mood 2.0                   1  neg  203.000   neg
# 555   post_mood 2.0                   1  neg  144.000   neg
# 556   post_mood 2.0                   1  neg  122.000   neg
# 557   post_mood 2.0                   1  neg  230.000   neg
# 558   post_mood 2.0                   1  neg  144.000   neg
# 559   post_mood 2.0                   1  neg  113.000   neg
# 560   post_mood 2.0                   1  neg  148.000   neg
# 561   post_mood 2.0                   1  neg  139.000   neg
# 562   post_mood 2.0                   1  neg  151.000   neg
# 563   post_mood 2.0                   1  neg  219.000   neg
# 564   post_mood 2.0                   1  neg  161.000   neg
# 565   post_mood 2.0                   1  neg  165.000   neg
# 566   post_mood 2.0                   1  neg  140.000   neg
# 567   post_mood 2.0                   1  neg  157.000   neg
# 568   post_mood 2.0                   1  neg  187.000   neg
# 569   post_mood 2.0                   1  neg  151.000   neg
# 570   post_mood 2.0                   1  neg  141.000   neg
# 571   post_mood 2.0                   1  neg  194.000   neg
# 572   post_mood 2.0                   1  neg  144.000   neg
# 573   post_mood 2.0                   1  neg  176.000   neg
# 574   post_mood 2.0                   1  neg  153.000   neg
# 575   post_mood 2.0                   1  neg  167.000   neg
# 576   post_mood 2.0                   1  neg  174.000   neg
# 577   post_mood 2.0                   1  neg  178.000   neg
# 578   post_mood 2.0                   1  neg  171.000   neg
# 579   post_mood 2.0                   1  neg  174.000   neg
# 580   post_mood 2.0                   1  neg  159.000   neg
# 581   post_mood 2.0                   1  neg  169.000   neg
# 582   post_mood 2.0                   1  neg  162.000   neg
# 583   post_mood 2.0                   1  neg  180.000   neg
# 584   post_mood 2.0                   1  neg  178.000   neg
# 585   post_mood 2.0                   1  neg  150.000   neg
# 586   post_mood 2.0                   1  neg  146.000   neg
# 587   post_mood 2.0                   1  neg  157.000   neg
# 588   post_mood 2.0                   1  neg  208.000   neg
# 589   post_mood 2.0                   1  neg  155.000   neg
# 590   post_mood 2.0                   1  neg  175.000   neg
# 591   post_mood 2.0                   1  neg  178.000   neg
# 592   post_mood 2.0                   1  neg  179.000   neg
# 593   post_mood 2.0                   1  neg  140.000   neg
# 594   post_mood 2.0                   1  neg  151.000   neg
# 595   post_mood 2.0                   1  neg  151.000   neg
# 596   post_mood 2.0                   1  neg  168.000   neg
# 597   post_mood 2.0                   1  neg  172.000   neg
# 598   post_mood 3.0                   1  neg  186.000   neg
# 599   post_mood 3.0                   1  neg  189.000   neg
# 600   post_mood 3.0                   1  neg  167.000   neg
# 601   post_mood 3.0                   1  neg  148.000   neg
# 602   post_mood 3.0                   1  neg  145.000   neg
# 603   post_mood 3.0                   1  neg  169.000   neg
# 604   post_mood 3.0                   1  neg  133.000   neg
# 605   post_mood 3.0                   1  neg  131.000   neg
# 606   post_mood 3.0                   1  neg  110.000   neg
# 607   post_mood 3.0                   1  neg  139.000   neg
# 608   post_mood 3.0                   1  neg  145.000   neg
# 609   post_mood 3.0                   1  neg  117.000   neg
# 610   post_mood 3.0                   1  neg  139.000   neg
# 611   post_mood 3.0                   1  neg  127.000   neg
# 612   post_mood 3.0                   1  neg  143.000   neg
# 613   post_mood 3.0                   1  neg  131.000   neg
# 614   post_mood 3.0                   1  neg  139.000   neg
# 615   post_mood 3.0                   1  neg  155.000   neg
# 616   post_mood 3.0                   1  neg  146.000   neg
# 617   post_mood 3.0                   1  neg  145.000   neg
# 618   post_mood 3.0                   1  neg  142.000   neg
# 619   post_mood 3.0                   1  neg  143.000   neg
# 620   post_mood 3.0                   1  neg  145.000   neg
# 621   post_mood 3.0                   1  neg  147.000   neg
# 622   post_mood 3.0                   1  neg  137.000   neg
# 623   post_mood 3.0                   1  neg  125.000   neg
# 624   post_mood 3.0                   1  neg  161.000   neg
# 625   post_mood 3.0                   1  neg  216.000   neg
# 626   post_mood 3.0                   1  neg  135.000   neg
# 627   post_mood 3.0                   1  neg  127.000   neg
# 628   post_mood 3.0                   1  neg  128.000   neg
# 629   post_mood 3.0                   1  neg  146.000   neg
# 630   post_mood 3.0                   1  neg  121.000   neg
# 631   post_mood 3.0                   1  neg  127.000   neg
# 632   post_mood 3.0                   1  neg  133.000   neg
# 633   post_mood 3.0                   1  neg  151.000   neg
# 634   post_mood 3.0                   1  neg  149.000   neg
# 635   post_mood 3.0                   1  neg  138.000   neg
# 636   post_mood 3.0                   1  neg  158.000   neg
# 637   post_mood 3.0                   1  neg  136.000   neg
# 638   post_mood 3.0                   1  neg  148.000   neg
# 639   post_mood 3.0                   1  neg  125.000   neg
# 640   post_mood 3.0                   1  neg  140.000   neg
# 641   post_mood 3.0                   1  neg  112.000   neg
# 642   post_mood 3.0                   1  neg  127.000   neg
# 643   post_mood 3.0                   1  neg  117.000   neg
# 644   post_mood 3.0                   1  neg  143.000   neg
# 645   post_mood 3.0                   1  neg  111.000   neg
# 646   post_mood 3.0                   1  neg  130.000   neg
# 647   post_mood 3.0                   1  neg  137.000   neg
# 648   post_mood 3.0                   1  neg  127.000   neg
# 649   post_mood 3.0                   1  neg  136.000   neg
# 650   post_mood 3.0                   1  neg  134.000   neg
# 651   post_mood 3.0                   1  neg  136.000   neg
# 652   post_mood 3.0                   1  neg  154.000   neg
# 653   post_mood 3.0                   1  neg  145.000   neg
# 654   post_mood 3.0                   1  neg  119.000   neg
# 655   post_mood 3.0                   1  neg  140.000   neg
# 656   post_mood 3.0                   1  neg  176.000   neg
# 657   post_mood 3.0                   1  neg  123.000   neg
# 658   post_mood 4.0                   1  neg  141.000   neg
# 659   post_mood 4.0                   1  neg  122.000   neg
# 660   post_mood 4.0                   1  neg  151.000   neg
# 661   post_mood 4.0                   1  neg  105.000   neg
# 662   post_mood 4.0                   1  neg  167.000   neg
# 663   post_mood 4.0                   1  neg  134.000   neg
# 664   post_mood 4.0                   1  neg  122.000   neg
# 665   post_mood 4.0                   1  neg  130.000   neg
# 666   post_mood 4.0                   1  neg  161.000   neg
# 667   post_mood 4.0                   1  neg  104.000   neg
# 668   post_mood 4.0                   1  neg  154.000   neg
# 669   post_mood 4.0                   1  neg  187.000   neg
# 670   post_mood 4.0                   1  neg  140.000   neg
# 671   post_mood 4.0                   1  neg  203.000   neg
# 672   post_mood 4.0                   1  neg  145.000   neg
# 673   post_mood 4.0                   1  neg  207.000   neg
# 674   post_mood 4.0                   1  neg  232.000   neg
# 675   post_mood 4.0                   1  neg  157.000   neg
# 676   post_mood 4.0                   1  neg  209.000   neg
# 677   post_mood 4.0                   1  neg  112.000   neg
# 678   post_mood 4.0                   1  neg  143.000   neg
# 679   post_mood 4.0                   1  neg  136.000   neg
# 680   post_mood 4.0                   1  neg  184.000   neg
# 681   post_mood 4.0                   1  neg  160.000   neg
# 682   post_mood 4.0                   1  neg  121.000   neg
# 683   post_mood 4.0                   1  neg  122.000   neg
# 684   post_mood 4.0                   1  neg  137.000   neg
# 685   post_mood 4.0                   1  neg  141.000   neg
# 686   post_mood 4.0                   1  neg  146.000   neg
# 687   post_mood 4.0                   1  neg  125.000   neg
# 688   post_mood 4.0                   1  neg  157.000   neg
# 689   post_mood 4.0                   1  neg  181.000   neg
# 690   post_mood 4.0                   1  neg  105.000   neg
# 691   post_mood 4.0                   1  neg  159.000   neg
# 692   post_mood 4.0                   1  neg  106.000   neg
# 693   post_mood 4.0                   1  neg  107.000   neg
# 694   post_mood 4.0                   1  neg  149.000   neg
# 695   post_mood 4.0                   1  neg  135.000   neg
# 696   post_mood 4.0                   1  neg  141.000   neg
# 697   post_mood 4.0                   1  neg  124.000   neg
# 698   post_mood 4.0                   1  neg  119.000   neg
# 699   post_mood 4.0                   1  neg  200.000   neg
# 700   post_mood 4.0                   1  neg  159.000   neg
# 701   post_mood 4.0                   1  neg  136.000   neg
# 702   post_mood 4.0                   1  neg  131.000   neg
# 703   post_mood 4.0                   1  neg  119.000   neg
# 704   post_mood 4.0                   1  neg  133.000   neg
# 705   post_mood 4.0                   1  neg  131.000   neg
# 706   post_mood 4.0                   1  neg  131.000   neg
# 707   post_mood 4.0                   1  neg  137.000   neg
# 708   post_mood 4.0                   1  neg  155.000   neg
# 709   post_mood 4.0                   1  neg  137.000   neg
# 710   post_mood 4.0                   1  neg  132.000   neg
# 711   post_mood 4.0                   1  neg  127.000   neg
# 712   post_mood 4.0                   1  neg  170.000   neg
# 713   post_mood 4.0                   1  neg  224.000   neg
# 714   post_mood 4.0                   1  neg  191.000   neg
# 715   post_mood 4.0                   1  neg  123.000   neg
# 716   post_mood 4.0                   1  neg  136.000   neg
# 717   post_mood 4.0                   1  neg  142.000   neg
# 718  post_mood 15.0                   1  neg      nan   neg
# 719   post_mood 5.0                   1  neg  150.000   neg
# 720   post_mood 5.0                   1  neg  163.000   neg
# 721   post_mood 5.0                   1  neg  125.000   neg
# 722   post_mood 5.0                   1  neg  127.000   neg
# 723   post_mood 5.0                   1  neg  107.000   neg
# 724   post_mood 5.0                   1  neg  108.000   neg
# 725   post_mood 5.0                   1  neg  152.000   neg
# 726   post_mood 5.0                   1  neg  116.000   neg
# 727   post_mood 5.0                   1  neg  116.000   neg
# 728   post_mood 5.0                   1  neg  114.000   neg
# 729   post_mood 5.0                   1  neg  109.000   neg
# 730   post_mood 5.0                   1  neg  142.000   neg
# 731   post_mood 5.0                   1  neg  124.000   neg
# 732   post_mood 5.0                   1  neg  178.000   neg
# 733   post_mood 5.0                   1  neg  238.000   neg
# 734   post_mood 5.0                   1  neg  117.000   neg
# 735   post_mood 5.0                   1  neg  120.000   neg
# 736   post_mood 5.0                   1  neg  155.000   neg
# 737   post_mood 5.0                   1  neg  119.000   neg
# 738   post_mood 5.0                   1  neg  206.000   neg
# 739   post_mood 5.0                   1  neg  144.000   neg
# 740   post_mood 5.0                   1  neg  151.000   neg
# 741   post_mood 5.0                   1  neg  113.000   neg
# 742   post_mood 5.0                   1  neg  105.000   neg
# 743   post_mood 5.0                   1  neg  125.000   neg
# 744   post_mood 5.0                   1  neg  147.000   neg
# 745   post_mood 5.0                   1  neg  120.000   neg
# 746   post_mood 5.0                   1  neg  120.000   neg
# 747   post_mood 5.0                   1  neg  108.000   neg
# 748   post_mood 5.0                   1  neg  122.000   neg
# 749   post_mood 5.0                   1  neg  179.000   neg
# 750   post_mood 5.0                   1  neg  125.000   neg
# 751   post_mood 5.0                   1  neg  114.000   neg
# 752   post_mood 5.0                   1  neg  220.000   neg
# 753   post_mood 5.0                   1  neg  109.000   neg
# 754   post_mood 5.0                   1  neg  209.000   neg
# 755   post_mood 5.0                   1  neg  207.000   neg
# 756   post_mood 5.0                   1  neg  136.000   neg
# 757   post_mood 5.0                   1  neg  129.000   neg
# 758   post_mood 5.0                   1  neg  118.000   neg
# 759   post_mood 5.0                   1  neg  149.000   neg
# 760   post_mood 5.0                   1  neg  147.000   neg
# 761   post_mood 5.0                   1  neg  130.000   neg
# 762   post_mood 5.0                   1  neg  132.000   neg
# 763   post_mood 6.0                   1  neg  158.000   neg
# 764   post_mood 6.0                   1  neg  179.000   neg
# 765   post_mood 6.0                   1  neg  180.000   neg
# 766   post_mood 6.0                   1  neg  126.000   neg
# 767   post_mood 6.0                   1  neg  135.000   neg
# 768   post_mood 6.0                   1  neg  168.000   neg
# 769   post_mood 6.0                   1  neg  158.000   neg
# 770   post_mood 6.0                   1  neg  151.000   neg
# 771   post_mood 6.0                   1  neg  170.000   neg
# 772   post_mood 6.0                   1  neg  143.000   neg
# 773   post_mood 6.0                   1  neg  151.000   neg
# 774   post_mood 6.0                   1  neg  139.000   neg
# 775   post_mood 6.0                   1  neg  143.000   neg
# 776   post_mood 6.0                   1  neg  137.000   neg
# 777   post_mood 6.0                   1  neg  126.000   neg
# 778   post_mood 6.0                   1  neg  156.000   neg
# 779   post_mood 6.0                   1  neg  173.000   neg
# 780   post_mood 6.0                   1  neg  120.000   neg
# 781   post_mood 6.0                   1  neg  170.000   neg
# 782   post_mood 6.0                   1  neg  185.000   neg
# 783   post_mood 6.0                   1  neg  206.000   neg
# 784   post_mood 6.0                   1  neg  119.000   neg
# 785   post_mood 6.0                   1  neg  186.000   neg
# 786   post_mood 6.0                   1  neg  180.000   neg
# 787   post_mood 6.0                   1  neg  175.000   neg
# 788   post_mood 6.0                   1  neg  179.000   neg
# 789   post_mood 6.0                   1  neg  192.000   neg
# 790   post_mood 6.0                   1  neg  159.000   neg
# 791   post_mood 6.0                   1  neg  183.000   neg
# 792   post_mood 6.0                   1  neg  202.000   neg
# 793   post_mood 6.0                   1  neg  240.000   neg
# 794   post_mood 6.0                   1  neg  193.000   neg
# 795   post_mood 6.0                   1  neg  122.000   neg
# 796   post_mood 6.0                   1  neg  136.000   neg
# 797   post_mood 6.0                   1  neg  134.000   neg
# 798   post_mood 6.0                   1  neg  134.000   neg
# 799   post_mood 6.0                   1  neg  155.000   neg

# %%
data["block"] = data["round_instance"].map({
    1:"1st",
    2:"1st",
    3:"1st",
    4:"1st",
    5:"2nd",
    6:"2nd",
    7:"2nd",
    8:"2nd",
    9:"3rd",
    10:"3rd",
    11:"3rd",
    12:"3rd"
})

# %%
fish = data[(data.task == "fishing_pos")|(data.task == "fishing_neg")]

# %%
# response
rating = data[(data.task == "mood_rating_pos")|(data.task == "mood_rating_neg")]

# %%
data.Subject.nunique()
# Out:
# 59

# %%
rating["index"]=[1]*len(rating)
i = rating.groupby(["Subject", "environment"])["index"].cumsum().reset_index(name = "index")
rating = pd.merge(rating, i, left_on=rating.index, right_on = "level_0", how = "inner")
rating.drop(["index_x", "level_0"], axis = 1, inplace = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
rating.rename(columns={"index_y": "RatingNumber"}, inplace = True)

# %%
rating.RatingNumber.unique()
# Out:
# array([1, 2, 3])

# %% [markdown]
# # Mood Manipulation Graph

# %%
b = sns.FacetGrid(rating, col="label", col_order=["neg", "control"])
b = b.map(sns.lineplot, "RatingNumber", "response", "environment", err_style = None,
         marker="o")
# for ax in b.axes.ravel():
#     ax.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True)
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 1), shadow=True)
axes = b.axes.flatten()
axes[0].set_title("Neg Mood Manipulation (n = 30)")
axes[1].set_title("Control no WoF (n = 29)")
    
plt.savefig("rating_control_neg.png", transparent = True, dpi = 300, bbox_inches='tight')

# %%
# by subject scatterplot
mean_rating = rating[rating.environment == "pre_mood"].groupby("Subject").response.mean().reset_index(name = "mean")
std_rating = rating[rating.environment == "pre_mood"].groupby("Subject").response.std().reset_index(name = "std")
stats_pre = pd.merge(mean_rating, std_rating, on = 'Subject', how = "outer")

rating_post = rating[rating.environment == "post_mood"]
rating_post = rating_post.sort_values(by = "Subject")
stats_pre = stats_pre.sort_values(by = "Subject")
c = 0
z_scored = []
for s in stats_pre.Subject:
    subject = rating_post[rating_post.Subject == s]
    mean = stats_pre[stats_pre.Subject == s]["mean"][c]
    std = stats_pre[stats_pre.Subject == s]["std"][c]
    series = (subject.response - mean)/std
    z_scored.extend(series)
    c = c + 1

# %%
rating_post["z_scored"] = z_scored

# %%
# scatterplot for rating
r = rating.groupby(["Subject", "environment", "label"]).response.mean().reset_index(name = "mean")
p = r.pivot(index='Subject', columns='environment', values = "mean")
p = p.merge(r[["Subject", "label"]], on = "Subject")

# %%
sns.scatterplot(data=p, x="pre_mood", y="post_mood", hue="label")
lims = [
    np.min([0, 100]),  # min of both axes
    np.max([0, 100]),  # max of both axes
]

# now plot both limits against eachother
plt.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.xlabel("Pre Mood Manipulation/Break Rating")
plt.xlabel("Pose Mood Manipulation/Break Rating")
plt.title("Scatterplot of Ratings in Neg and Control (n = 59)")

plt.savefig("scatter_plot_ratings.png", transparent = True, dpi = 300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Average Latency by price

# %%
fish.price_displayed.unique()
# Out:
# array([2.5, 1. , 0.1, 0.4])

# %%
# scatterplot for latency
f = fish.groupby(["Subject", "environment", 'price_displayed', "label"]).latency.mean().reset_index(name = "mean")
post = f[f.environment == "post_mood"]
pre = f[f.environment == "pre_mood"]

# %%
post.rename(columns={"mean": "post"}, inplace = True)
pre.rename(columns={"mean": "pre"}, inplace = True)
l = pd.merge(post[["Subject", 'price_displayed', 'post', "label"]], pre[["Subject", 'price_displayed', 'pre']], on = ["Subject", "price_displayed"])

# %%
# scatter plot
# subjects of latency post vs pre for each price bin. 
# On the same plot show the negative and the no-wheel manipulations. 
# This will be a first step to understanding the differences between 
# negative and positive. So that's 4 scatter plots.


b = sns.FacetGrid(l, col="price_displayed", col_order=[0.1, 0.4, 1, 2.5])
b = b.map(sns.scatterplot, "pre", "post", "label")

plt.legend(loc='upper center', bbox_to_anchor=(1.45, 1), shadow=True)

axes = b.axes.flatten()
axes[0].plot([130, 226], [130, 226])
axes[1].plot([130, 226], [130, 226])
axes[2].plot([130, 226], [130, 226])
axes[3].plot([130, 226], [130, 226])
axes[0].set_aspect('equal')
# plt.xlabel("Avg Latency Pre Mood Manipulation/Break (ms)")
# plt.xlabel("Avg Latency Pose Mood Manipulation/Break (ms)")
# plt.title("Scatterplot of latency in Neg and Control (n = 59)")

plt.savefig("scatter_plot_latencys.png", transparent = True, dpi = 300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Average Latency

# %%
b = sns.FacetGrid(fish, col="label", col_order=["neg", "control"])
b = b.map(sns.lineplot, "price_displayed", "latency", "environment",
         err_style = "bars")
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 1), shadow=True)

axes = b.axes.flatten()
axes[0].set_title("Neg Mood Manipulation (n = 30)")
axes[1].set_title("Control no WoF (n = 29)")
axes[0].set_ylabel("Latency (ms)")
axes[0].set_xlabel("Price")
axes[0].set_xlabel("Price")

plt.savefig("average_latency_neg_control.png", transparent = True, dpi = 300, 
            bbox_inches='tight')
plt.show()

# %%
mood_graph_pre = fish[(fish.environment == "pre_mood")]
anova = mood_graph_pre.groupby(["Subject", "mood"])['latency'].mean().reset_index(name = "latency")

# %%
# mood graph
mood_graph_post = fish[(fish.environment == "post_mood")]
g = mood_graph_post.groupby(["environment","mood","price_displayed"])['latency'].mean().reset_index()

# %%
g
# Out:
#   environment mood  price_displayed  latency
# 0   post_mood  neg            0.100  157.662
# 1   post_mood  neg            0.400  159.032
# 2   post_mood  neg            1.000  159.636
# 3   post_mood  neg            2.500  157.530

# %%
price = [0.1, 0.6,2.5, 6.0]
# latency_p = g.latency[(g.mood == 'pos')]
latency_n = g.latency[(g.mood == 'neg')]

# %%
data.Subject.nunique()
# Out:
# 30

# %%
# plt.plot( price,  latency_pre_n, marker='', color='purple', linewidth=2, label = "pre-mood")
# plt.plot( price, latency_n, marker='', color='black', linewidth=2, linestyle='dashed', label="post-mood")

sns.lineplot("price_displayed", "latency", marker='o', color='purple', data = mood_graph_pre,label = "pre", err_style='bars')
sns.lineplot("price_displayed", "latency", marker='o', color='black', data = mood_graph_post,label = "post", err_style='bars')


plt.title("Action Initiation Latency after NEGATIVE Mood Manipulation (n = 30)")
plt.xlabel("Price")
plt.ylabel("Average Latency (ms)")
plt.legend()
plt.ylim([135, 215])
plt.savefig('price_latency_after_NEG_mood.png', transparent=True, dpi=300)

# %%
latency_pre_n = mood_graph_pre.groupby(["price_displayed"])["latency"].median()
latency_n = mood_graph_post.groupby(["price_displayed"])["latency"].median()
price = [0.1, 0.4, 1, 2.5]
plt.plot( price,  latency_pre_n, marker='', color='purple', linewidth=2, label = "pre-mood")
plt.plot( price, latency_n, marker='', color='black', linewidth=2, linestyle='dashed', label="post-mood")

plt.legend()

# %% [markdown]
# # by block

# %%
data.block.unique()
# Out:
# array(['1st', '2nd', '3rd', nan], dtype=object)

# %%
r = sns.FacetGrid(fish, col="environment", row = "label", gridspec_kws={"wspace":1})
r.map(sns.lineplot, "price_displayed", "latency", "block", marker="o", err_style='bars', hue_order = ['1st', '2nd', '3rd'])
# for ax in r.axes.ravel():
#     ax.legend(loc='upper center')
# plt.legend(loc='upper center', bbox_to_anchor=(1.2, 0.9), shadow=True)
plt.legend()
# plt.savefig("latency_by_subject_ordered_no_wof.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # box plot

# %%
# Box plot Difference 
# of post minus pre latencies 
# at each price bin 
# for NEG and no-wof manipulations. 
# So you should have 1 plot with 8 bars: 
# price=0.1 NEG, price = 0.1 NULL, ...., price = 2.5 NEG, price = 2.5 NULL
l["diff"] = l['post'] - l["pre"]
l["tag"] = l["label"] + " " +l["price_displayed"].astype(str)
sns.boxplot(x="tag", y="diff", data=l)
plt.xticks(rotation = 45, ha="right")
plt.title("Post - Pre diff (ms) (n = 59)")
plt.savefig('box_plot_pre_post_diff.png', transparent=True, dpi=300)

# %% [markdown]
# # Rating

# %%
# response
rating = data[(data.task == "mood_rating_pos")|(data.task == "mood_rating_neg")]

# %%
rating["index"]=[1]*len(rating)
i = rating.groupby(["Subject", "environment"])["index"].cumsum().reset_index(name = "index")
rating = pd.merge(rating, i, left_on=rating.index, right_on = "level_0", how = "inner")
rating.drop(["index_x", "level_0"], axis = 1, inplace = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
rating["mood"] = rating["task"].map({"mood_rating_pos":"pos",
                                    "mood_rating_neg":"neg"})

# %%
rating["name"] = rating["Subject"].astype(int).astype(str) + " " + rating["mood"]

# %%
r = sns.FacetGrid(rating, col="name", col_wrap=2, height=3, ylim=(0, 100))
r.map(sns.lineplot, "index_y", "response", "environment", marker="o")
for ax in r.axes.ravel():
    ax.legend()
    ax.set_ylabel("Rating")
    ax.set_xlabel("Rating Number")
    
# plt.xlabel("Rating Number")
# plt.ylabel("Rating Number")
plt.xticks([1, 2, 3])
plt.savefig("rating_by_subject_NEG.png", transparent=True, dpi=300)
# g = sns.FacetGrid(plot, col="id", col_wrap=4, height=2, ylim=(50, 300))
# g.map(sns.lineplot,'price_displayed','average_latency', 'environment', palette = "GnBu_d", legend = 'full',
#       err_style="bars")

# %%
sns.lineplot("index_y", "response", "environment", markers=True, ci = None,marker = "o", data = rating)
plt.xlabel("Rating Number")
plt.ylabel("Rating")
plt.xticks([1, 2, 3])
plt.ylim([58, 76])
plt.title("Mood Rating Pre and Post Mood Manipulation (n = 30)")
plt.savefig("NEG mood raitng", dpi = 300, transparent = True)

# %%
ax = sns.boxplot(x="index_y", y="response", hue="environment",
                 data=rating, palette="Set3")
ax.legend(loc = 1, bbox_to_anchor = (1.3, 0.5))
plt.savefig("rating_boxplot.png", dpi = 300, transparent = True, bbox_inches='tight')

# %%
mean_rating = rating[rating.environment == "pre_mood"].groupby("Subject").response.mean().reset_index(name = "mean")
std_rating = rating[rating.environment == "pre_mood"].groupby("Subject").response.std().reset_index(name = "std")

# %%
stats_pre = pd.merge(mean_rating, std_rating, on = 'Subject', how = "outer")

# %%
rating_post = rating[rating.environment == "post_mood"]

# %%
rating_post = rating_post.sort_values(by = "Subject")
stats_pre = stats_pre.sort_values(by = "Subject")

# %%
c = 0
z_scored = []
for s in stats_pre.Subject:
    subject = rating_post[rating_post.Subject == s]
    mean = stats_pre[stats_pre.Subject == s]["mean"][c]
    std = stats_pre[stats_pre.Subject == s]["std"][c]
    series = (subject.response - mean)/std
    z_scored.extend(series)
    c = c + 1

# %%
rating_post["z_scored"] = z_scored

# %%
# rating_post
#1932474.000 # rated all 100
#1932604.000 # rated all 100 expect for the one after mood manipulation for a 95

# %%
# b = sns.FacetGrid(rating, col="mood", col_order=["pos", "neg"])
# b = b.map(sns.lineplot, "index_y", "response","environment", markers=True, ci = None)
# plt.legend(loc='upper center', bbox_to_anchor=(1.45, 1), shadow=True)
# axes = b.axes.flatten()
# axes[0].set_title("mood = pos (n = 13)")
# axes[1].set_title("mood = neg (n = 16)")
    
# plt.savefig("average_rating_29.png", transparent = True, dpi = 300, bbox_inches='tight')

# %%
# b = sns.FacetGrid(rating[rating.Subject != 1912556], col="mood", col_order=["pos", "neg"])
# b = b.map(sns.lineplot, "index_y", "response","environment", markers=True, ci = None)
# plt.legend(loc='upper center', bbox_to_anchor=(1.45, 1), shadow=True)
# axes = b.axes.flatten()
# axes[0].set_title("mood = pos (n = 12)")
# axes[1].set_title("mood = neg (n = 16)")
    
# plt.savefig("average_rating_28.png", transparent = True, dpi = 300, bbox_inches='tight')

# %% [markdown]
# # Look at neg and pos seperately?

# %%
fish.head()
# Out:
#       Subject     UTC Timestamp  key pressed  price_displayed environment  \
# 5 1932451.000 1599581939262.000       40.000            2.500    pre_mood
# 6 1932451.000 1599581939418.000       40.000            2.500    pre_mood
# 7 1932451.000 1599581939418.000       40.000            2.500    pre_mood
# 8 1932451.000 1599581939793.000       40.000            2.500    pre_mood
# 9 1932451.000 1599581940121.000       40.000            2.500    pre_mood
#
#           task  function id  builtin rt          end_time     start_time  \
# 5  fishing_neg  fishing_neg     184.950 1599581938854.000  1599581938668
# 6  fishing_neg  fishing_neg      14.760 1599581938972.000  1599581938957
# 7  fishing_neg  fishing_neg      48.420 1599581939122.000  1599581939074
# 8  fishing_neg  fishing_neg      95.305 1599581939323.000  1599581939227
# 9  fishing_neg  fishing_neg     310.810 1599581939738.000  1599581939427
#
#    response  round_instance   trial_label  environment_binary  latency mood
# 5       nan           1.000  pre_mood 1.0                   0  289.000  neg
# 6       nan           1.000  pre_mood 1.0                   0  117.000  neg
# 7       nan           1.000  pre_mood 1.0                   0  153.000  neg
# 8       nan           1.000  pre_mood 1.0                   0  200.000  neg
# 9       nan           1.000  pre_mood 1.0                   0  418.000  neg

# %%
# b = sns.FacetGrid(fish, col="mood", col_order=["pos", "neg"])
# b = b.map(sns.lineplot, "price_displayed", "latency", "environment",
#          err_style = "bars")
# plt.tight_layout()
# plt.legend(loc='upper center', bbox_to_anchor=(1.2, 0.9), shadow=True)

# plt.savefig("average_latency_pos_neg.png", transparent = True, dpi = 300, 
#             bbox_inches='tight')
# plt.show()

# %% [markdown]
# # by subject plot

# %%
fish.head(1)
# fish["title"] = fish["Subject"].astype(str) + " " + fish["mood"]
# Out:
#       Subject     UTC Timestamp  key pressed  price_displayed environment  \
# 5 1932451.000 1599581939262.000       40.000            2.500    pre_mood
#
#           task  function id  builtin rt          end_time     start_time  \
# 5  fishing_neg  fishing_neg     184.950 1599581938854.000  1599581938668
#
#    response  round_instance   trial_label  environment_binary  latency mood
# 5       nan           1.000  pre_mood 1.0                   0  289.000  neg

# %%
# f = fish.groupby(["title", "environment", "price_displayed"])["latency"].mean().reset_index(name = "avg")

# %%
sum_rating = rating.groupby(["Subject", "environment"])["response"].mean().reset_index(name = "avg_rating")

# %%
sum_rating["diff"] = sum_rating.groupby("Subject")["avg_rating"].diff(periods=-1)

# %%
sum_rating = sum_rating.dropna()

# %%
fish = fish.merge(sum_rating[["Subject", "diff"]], on = "Subject", how = "left")

# %%
fish = fish.sort_values(by = "diff")

# %%
fish["title"] = fish["Subject"].astype(str) + " diff: " + fish["diff"].round(2).astype(str)

# %%
r = sns.FacetGrid(fish, col="title", col_wrap=2, height=3, ylim = ([100, 280]))
r.map(sns.lineplot, "price_displayed", "latency", "environment", marker="o", err_style='bars', hue_order = ["pre_mood", "post_mood"])
for ax in r.axes.ravel():
    ax.legend(loc='upper center')
plt.legend(loc='upper center', bbox_to_anchor=(1.2, 0.9), shadow=True)
plt.savefig("latency_by_subject_ordered_NEG.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %%
# 1932550

# %%
r = sns.FacetGrid(f, col="title", col_wrap=2, height=3, ylim = ([100, 280]))
r.map(sns.lineplot, "price_displayed", "avg", "environment", marker="o")
for ax in r.axes.ravel():
    ax.legend(loc='upper center')
plt.legend(loc='upper center', bbox_to_anchor=(1.2, 0.9), shadow=True)
plt.savefig("latency_by_subject_NEG.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # tap difference

# %%
tap = fish.groupby(["Subject", "environment"]).size().reset_index(name = "tap")

# %%
t = tap.groupby("Subject").tap.diff(periods = -1)

# %%
tap["tap_diff"] = t

# %%
tap = tap.dropna()

# %%
rating_tap_diff = pd.merge(sum_rating, tap[["Subject", "tap_diff"]], on = "Subject")

# %%
ss.spearmanr(rating_tap_diff["diff"], rating_tap_diff["tap_diff"])
# Out:
# SpearmanrResult(correlation=0.08336115800099134, pvalue=0.6614222432513891)

# %% [markdown]
# ## Robb's version

# %%
# rating_post
#1932474.000 # rated all 100
#1932604.000 # rated all 100 expect for the one after mood manipulation for a 95
rating_post = rating_post[~rating_post.Subject.isin([1932474.000, 1932604.000])]
tap = tap[~tap.Subject.isin([1932474.000, 1932604.000])]

# %%
m = rating_post.groupby("Subject").z_scored.mean().reset_index(name = 'm_zscored')
tap = pd.merge(tap, m, on = "Subject", how = "outer")

# %%
ss.spearmanr(tap["tap_diff"], tap["m_zscored"])
# Out:
# SpearmanrResult(correlation=0.16153321006257568, pvalue=0.4115341340777794)

# %% [markdown]
# # Mood change and HPS

# %%
hps = pd.read_csv("/Users/SophieS/Desktop/hps_neg.csv")

# %%
hps = hps.merge(tap, on = "Subject")

# %%
hps
# Out:
#     Unnamed: 0     Subject  score environment  tap  tap_diff  m_zscored
# 0            0 1932451.000  2.500   post_mood  694    91.000     -2.127
# 1            1 1932455.000  3.417   post_mood  781   -21.000     -2.598
# 2            2 1932457.000  2.917   post_mood  735    27.000     -1.574
# 3            3 1932462.000  2.167   post_mood  693    -9.000      0.555
# 4            4 1932463.000  1.750   post_mood  771    20.000      1.601
# 5            6 1932490.000  3.333   post_mood  688   -14.000     -1.994
# 6            7 1932493.000  1.667   post_mood  731   -13.000     -5.000
# 7            8 1932507.000  3.083   post_mood  616   -75.000     -4.500
# 8            9 1932509.000  3.083   post_mood  778    11.000      0.218
# 9           10 1932510.000  3.250   post_mood  655   -56.000     -1.763
# 10          11 1932515.000  2.000   post_mood  795    43.000     -1.443
# 11          12 1932516.000  1.417   post_mood  577  -105.000     -3.603
# 12          13 1932518.000  1.750   post_mood  641   -50.000      0.431
# 13          14 1932520.000  3.167   post_mood  532   -33.000     -4.667
# 14          15 1932521.000  2.083   post_mood  563   -42.000     -1.606
# 15          16 1932522.000  3.583   post_mood  684    19.000     -5.563
# 16          17 1932544.000  2.000   post_mood  786    34.000     -1.960
# 17          18 1932546.000  2.667   post_mood  678    31.000      0.577
# 18          19 1932547.000  3.250   post_mood  654   -23.000     -1.354
# 19          20 1932550.000  3.000   post_mood   23    -1.000      1.155
# 20          21 1932560.000  3.917   post_mood  832    -1.000     -2.033
# 21          22 1932571.000  1.583   post_mood  670   -36.000     -0.609
# 22          23 1932591.000  2.583   post_mood  701   -22.000     -0.801
# 23          24 1932595.000  2.667   post_mood  693    14.000     -1.540
# 24          26 1932632.000  2.917   post_mood  870     3.000     -1.465
# 25          27 1932686.000  2.333   post_mood  596     3.000     -5.765
# 26          28 1932763.000  2.833   post_mood  695   -50.000     -1.058
# 27          29 1932999.000  4.083   post_mood  521    79.000     -0.102

# %%
ss.spearmanr(hps["score"], hps["m_zscored"])
# Out:
# SpearmanrResult(correlation=-0.1624213092825628, pvalue=0.4089330500027326)

# %%
ss.pearsonr(hps["score"], hps["tap_diff"])
# Out:
# (0.22554703570879175, 0.24849396729132572)

# %%
# z-scored post ratings

# %% [markdown]
# # median latency between high and low

# %%
fish.Subject.nunique()
# Out:
# 30

# %%
m = fish.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")

# %%
m = m[m.price_displayed.isin([0.1, 2.5])]

# %%
diff = m.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)

# %%
m["diff"] = diff

# %%
m = m.dropna()

# %%
np.median(m["diff"]*(-1))
# Out:
# 9.0

# %%
# only pre-mood

# %%
m_pre_mood = fish[fish.environment == "pre_mood"]

# %%
m_pre_mood = m_pre_mood.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")

# %%
m_pre_mood = m_pre_mood[m_pre_mood.price_displayed.isin([0.1, 2.5])]

# %%
diff_pre_mood = m_pre_mood.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)

# %%
m_pre_mood["diff"] = diff_pre_mood

# %%
m_pre_mood = m_pre_mood.dropna()

# %%
np.median(m_pre_mood["diff"]*(-1))
# Out:
# 11.5

# %%
f_1 = fish[fish.trial_label.isin(['pre_mood 1.0',
                                 'pre_mood 2.0',
                                 'pre_mood 3.0',
                                 'pre_mood 4.0'])]

# %%
f_2 = fish[fish.trial_label.isin(['pre_mood 5.0',
                                 'pre_mood 6.0',
                                 'pre_mood 7.0',
                                 'pre_mood 8.0'])]

# %%
m_pre_mood_1 = f_1.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")
m_pre_mood_1 = m_pre_mood_1[m_pre_mood_1.price_displayed.isin([0.1, 6])]
diff_pre_mood_1 = m_pre_mood_1.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)
m_pre_mood_1["diff"] = diff_pre_mood_1
m_pre_mood_1 = m_pre_mood_1.dropna()
np.median(m_pre_mood_1["diff"]*(-1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
m_pre_mood_2 = f_2.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")
m_pre_mood_2 = m_pre_mood_2[m_pre_mood_2.price_displayed.isin([0.1, 6])]
diff_pre_mood_2 = m_pre_mood_2.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)
m_pre_mood_2["diff"] = diff_pre_mood_2
m_pre_mood_2 = m_pre_mood_2.dropna()
np.median(m_pre_mood_2["diff"]*(-1))
# Out:
# 27.5

# %%
from scipy import stats as ss

# %%
ss.ttest_rel(m_pre_mood_2["diff"], m_pre_mood_1["diff"])
# Out:
# Ttest_relResult(statistic=0.5036211665131262, pvalue=0.6184670833033181)

# %%
# post-mood overall

# %%
m_post_mood = fish[fish.environment == "post_mood"]

# %%
m_post_mood.shape
# Out:
# (19940, 17)

# %%
m_post_mood = m_post_mood.groupby(["Subject","price_displayed"])["latency"].median().reset_index(name = "median")
m_post_mood = m_post_mood[m_post_mood.price_displayed.isin([0.1, 2.5])]
diff_post_mood = m_post_mood.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)
m_post_mood["diff"] = diff_post_mood
m_post_mood = m_post_mood.dropna()
np.median(m_post_mood["diff"]*(-1))
# Out:
# 0.5

# %%
# post-mood positive

# %%
m_pos = fish[(fish.mood == "pos")&(fish.environment == "post_mood")]

# %%
m_pos = m_pos.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")

# %%
m_pos= m_pos[m_pos.price_displayed.isin([0.1, 6])]

# %%
diff_pos_mood = m_pos.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)

# %%
m_pos["diff"] = diff_pos_mood

# %%
m_pos = m_pos.dropna()

# %%
np.median(m_pos ["diff"]*(-1))
# Out:
# 1.0

# %%
m_post_mood = fish[fish.environment == "post_mood"]

# %%
m_neg = m_post_mood[m_post_mood.mood == "neg"]

# %%
m_neg = m_neg.groupby(["Subject", "price_displayed"])["latency"].median().reset_index(name = "median")

# %%
m_neg= m_neg[m_neg.price_displayed.isin([0.1, 6])]

# %%
diff_neg_mood = m_neg.groupby(["Subject"], as_index = True)["median"].diff().shift(-1)

# %%
m_neg["diff"] = diff_neg_mood

# %%
m_neg = m_neg.dropna()

# %%
np.median(m_neg ["diff"]*(-1))
# Out:
# 0.5

# %% [markdown]
# # Log Linear Mixed Model

# %%
from statsmodels.formula.api import mixedlm

# %%
# calculate fatigue
fish["tap_count"] = [1] * len(fish)
tap_count = fish.groupby(['Subject', 'trial_label'])['tap_count'].cumsum().reset_index(name = "fatigue")
tap_count = tap_count.reset_index().set_index("index")
tap_count = tap_count.drop("level_0", axis = 1)

# %%
fish = tap_count.merge(fish, left_index = True, right_index = True, how = "inner")

# %%
fish["log_latency"] = np.log(fish["latency"])

# %%
fish.environment_binary.unique()
# Out:
# array([0, 1])

# %%
fish.price_displayed.unique()
# Out:
# array([2.5, 1. , 0.1, 0.4])

# %%
fish.latency.isnull().values.any()
fish = fish[fish.latency.notnull()]

# %%
fish.head(1)
# Out:
#    fatigue     Subject     UTC Timestamp  key pressed  price_displayed  \
# 5        1 1932451.000 1599581939262.000       40.000            2.500
#
#   environment         task  function id  builtin rt          end_time  \
# 5    pre_mood  fishing_neg  fishing_neg     184.950 1599581938854.000
#
#       start_time  response  round_instance   trial_label  environment_binary  \
# 5  1599581938668       nan           1.000  pre_mood 1.0                   0
#
#    latency mood  tap_count  log_latency
# 5  289.000  neg          1        5.666

# %%
fish_pre = fish[fish.environment == "pre_mood"]
fish_post = fish[fish.environment == "post_mood"]

# %%
f_model = mixedlm(formula = "log_latency ~ 1 + environment_binary + price_displayed + fatigue",
                 groups = fish["Subject"],
                 re_formula = "~ environment_binary + price_displayed + fatigue", data = fish)
r = f_model.fit(reml = False, method = "powell")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
print (r.summary())
# Out:
#                        Mixed Linear Model Regression Results
# ===================================================================================
# Model:                      MixedLM         Dependent Variable:         log_latency
# No. Observations:           39451           Method:                     ML
# No. Groups:                 30              Scale:                      0.0574
# Min. group size:            23              Likelihood:                 144.2077
# Max. group size:            1713            Converged:                  Yes
# Mean group size:            1315.0
# -----------------------------------------------------------------------------------
#                                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------
# Intercept                                 5.216    0.058 89.493 0.000  5.102  5.330
# environment_binary                       -0.006    0.014 -0.450 0.653 -0.034  0.021
# price_displayed                          -0.022    0.009 -2.524 0.012 -0.040 -0.005
# fatigue                                  -0.002    0.001 -2.825 0.005 -0.003 -0.001
# Group Var                                 0.101    0.115
# Group x environment_binary Cov           -0.019    0.031
# environment_binary Var                    0.006    0.010
# Group x price_displayed Cov               0.005    0.017
# environment_binary x price_displayed Cov -0.001    0.005
# price_displayed Var                       0.002    0.004
# Group x fatigue Cov                      -0.001    0.001
# environment_binary x fatigue Cov          0.000    0.000
# price_displayed x fatigue Cov            -0.000    0.000
# fatigue Var                               0.000    0.000
# ===================================================================================

# %%
r_params = pd.DataFrame(r.params, columns = ["LMM"])
random_effects = pd.DataFrame(r.random_effects)
random_effects = random_effects.transpose()
random_effects = random_effects.rename(index = str, columns = {"group":"LMM"})

# %%
f_pre = mixedlm(formula = "log_latency ~ 1 + price_displayed + fatigue",
                 groups = fish_pre["Subject"],
                 re_formula = "~ price_displayed + fatigue", data = fish_pre)
r_pre = f_pre.fit(reml = False, method = "powell")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
print (r_pre.summary())
# Out:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      log_latency
# No. Observations:      19870        Method:                  ML
# No. Groups:            30           Scale:                   0.0541
# Min. group size:       12           Likelihood:              601.7692
# Max. group size:       855          Converged:               Yes
# Mean group size:       662.3
# ------------------------------------------------------------------------
#                               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                      5.246    0.064 81.917 0.000  5.121  5.372
# price_displayed               -0.053    0.014 -3.703 0.000 -0.081 -0.025
# fatigue                       -0.001    0.000 -2.962 0.003 -0.002 -0.000
# Group Var                      0.122    0.146
# Group x price_displayed Cov   -0.006    0.037
# price_displayed Var            0.006    0.010
# Group x fatigue Cov           -0.001    0.001
# price_displayed x fatigue Cov  0.000    0.000
# fatigue Var                    0.000    0.000
# ========================================================================

# %%
f_post = mixedlm(formula = "log_latency ~ 1 + environment + price_displayed + fatigue",
                 groups = fish_post["Subject"],
                 re_formula = "~ environment + price_displayed + fatigue", data = fish_post)
r_post = f_post.fit(reml = False, method = "powell")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
print (r_post.summary())
# Out:
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM      Dependent Variable:      log_latency
# No. Observations:       19581        Method:                  ML
# No. Groups:             30           Scale:                   0.0572
# Min. group size:        11           Likelihood:              66.1158
# Max. group size:        858          Converged:               Yes
# Mean group size:        652.7
# -------------------------------------------------------------------------
#                               Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                      5.176    0.044 118.507 0.000  5.090  5.261
# price_displayed                0.006    0.011   0.527 0.598 -0.015  0.026
# fatigue                       -0.002    0.001  -2.749 0.006 -0.003 -0.000
# Group Var                      0.057    0.067
# Group x price_displayed Cov    0.006    0.015
# price_displayed Var            0.003    0.006
# Group x fatigue Cov           -0.001    0.001
# price_displayed x fatigue Cov -0.000    0.000
# fatigue Var                    0.000    0.000
# =========================================================================

# %%
f_pre_avg = fish_pre.groupby("Subject")["latency"].mean().reset_index(name = "avg_across")
f_post_avg = fish_post.groupby("Subject")["latency"].mean().reset_index(name = "avg_across")

# %%
ss.wilcoxon(f_pre_avg.avg_across, f_post_avg.avg_across)
# Out:
# WilcoxonResult(statistic=199.0, pvalue=0.49079849348995086)

# %%
f_pre_avg = fish_pre.groupby("Subject")["latency"].median().reset_index(name = "avg_across_pre")
f_post_avg = fish_post.groupby("Subject")["latency"].median().reset_index(name = "avg_across_post")

# %%
ss.wilcoxon(f_pre_avg.avg_across_pre, f_post_avg.avg_across_post)
# Out:
# WilcoxonResult(statistic=188.5, pvalue=0.36509377246560404)

# %%
medians = f_pre_avg.merge(f_post_avg, on = "Subject")

# %%
medians.shape
# Out:
# (30, 3)

# %%
m = medians[medians.Subject != 1932550]

# %%
plt.scatter(m["avg_across_pre"], m["avg_across_post"])
plt.xlabel("Median Latency Pre Mood Manipulation(ms)")
plt.ylabel("Median Latency Post Mood Manipulation(ms)")

lims = [
    np.min([plt.gca().get_xlim(), plt.gca().get_ylim()]),  # min of both axes
    np.max([plt.gca().get_xlim(), plt.gca().get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
plt.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
plt.title("Scatter plot of medians for all prices (n = 29)")
plt.savefig("scatter plot medians.png", dpi = 300, transparent = True)

# %%
ss.wilcoxon(m["avg_across_pre"], m["avg_across_post"])
# Out:
# WilcoxonResult(statistic=158.5, pvalue=0.20165471306805094)
